# %% [markdown]
# <a href="https://colab.research.google.com/github/Dugi000/Ulsan/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%A7%88%EC%9D%B4%EB%8B%9D_Term_Project_%EC%84%B1%EB%AA%85_%ED%95%99%EB%B2%88_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[Term Project] 자동차 생산 공정 데이터 분석을 통한 생산성 개선 방안 도출**

# %% [markdown]
# - 이름:
# - 학번:

# %% [markdown]
# # 1. 문제 정의

# %% [markdown]
# # 2. 데이터 준비

# %% [markdown]
# ## 데이터 불러오기

# %%
# !gdown 1AX7tq815PP3FHIBrZZgYJZAt42cAAucf # process.xlsx
# !gdown 13fUZ_74qQ9b1KhIlVRU7KuDygxCW6Nxa # worker.xlsx

# %%
import pandas as pd

process_df = pd.read_excel('process.xlsx')
process_df

# %%
worker_df = pd.read_excel('worker.xlsx')
worker_df

# %%
merged_df = pd.merge(process_df, worker_df, left_on='작업자_사번', right_on='사번', how='left')
merged_df

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# # 3. EDA

# %% [markdown]
# ## 가설
# 1.
# 2.
# 3.
# 4.
# <br>...

# %% [markdown]
# # 4. 데이터 분석

# %% [markdown]
# # 5. 결론

# %% [markdown]
# # 참고문헌
